# %% [markdown]
# # Introduction to Data Science Team Project
#
# ## CCTV는 정말로 범죄를 예방하는 효과가 있을까?
#
# - [CCTV 설치로 범죄율 27% 감소](https://www.boannews.com/media/view.asp?idx=63961) 검증
#
#
# ##### 데이터셋
# - [서울시 자치구 년도별 CCTV 설치 현황](https://data.seoul.go.kr/dataList/OA-2734/C/1/datasetView.do)
# - [서울시 5대 범죄 발생현황 통계](https://data.seoul.go.kr/dataList/316/C/2/datasetView.do;jsessionid=2199F74D80737F2EC64059AC30470780.new_portal-svr-11)
#
# ### Import data

# %%
import pandas as pd
import numpy as np

import platform
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

path = "c:/Windows/Fonts/malgun.ttf"
from matplotlib import font_manager, rc
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')    

plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# #### 서울시 5대 범죄 발생현황 통계 데이터

# %%
# 왜 thousands가 작동안할까? 
crime = pd.read_csv('서울시 5대 범죄 발생현황 통계.csv', thousands=',', encoding='utf-8')
crime.head()
# Out:
#      기간  자치구       합계    합계.1   살인 살인.1   강도 강도.1 강간강제추행 강간강제추행.1      절도  \
# 0    기간  자치구       발생      검거   발생   검거   발생   검거     발생       검거      발생
# 1  2018   합계  101,948  74,487  143  139  143  151  6,412    6,046  39,175
# 2  2018  종로구    3,690   3,913    6    7    3    7    236    1,100   1,483
# 3  2018   중구    4,030   2,679    2    2   11   11    207      115   1,855
# 4  2018  용산구    3,411   2,543    1    1    3    2    331      285   1,096
#
#      절도.1      폭력    폭력.1
# 0      검거      발생      검거
# 1  19,762  56,075  48,389
# 2     969   1,962   1,830
# 3     832   1,955   1,719
# 4     522   1,980   1,733

# %%
columns_name = ['기간', '구별','합계 발생','합계 검거','살인 발생','살인 검거','강도 발생','강도 검거',
                '강간강제추행 발생', '강간강제추행 검거','절도 발생','절도 검거','폭력 발생','폭력 검거']
crime.columns = columns_name
crime.head()
# Out:
#      기간   구별    합계 발생   합계 검거 살인 발생 살인 검거 강도 발생 강도 검거 강간강제추행 발생 강간강제추행 검거  \
# 0    기간  자치구       발생      검거    발생    검거    발생    검거        발생        검거
# 1  2018   합계  101,948  74,487   143   139   143   151     6,412     6,046
# 2  2018  종로구    3,690   3,913     6     7     3     7       236     1,100
# 3  2018   중구    4,030   2,679     2     2    11    11       207       115
# 4  2018  용산구    3,411   2,543     1     1     3     2       331       285
#
#     절도 발생   절도 검거   폭력 발생   폭력 검거
# 0      발생      검거      발생      검거
# 1  39,175  19,762  56,075  48,389
# 2   1,483     969   1,962   1,830
# 3   1,855     832   1,955   1,719
# 4   1,096     522   1,980   1,733

# %%
crime.drop([0,1], inplace=True)
crime.drop('기간',1, inplace=True) # 모두 2018년 데이터이므로! 
crime.reset_index(drop=True, inplace=True)
crime.head()
# Out:
#     구별  합계 발생  합계 검거 살인 발생 살인 검거 강도 발생 강도 검거 강간강제추행 발생 강간강제추행 검거  절도 발생 절도 검거  \
# 0  종로구  3,690  3,913     6     7     3     7       236     1,100  1,483   969
# 1   중구  4,030  2,679     2     2    11    11       207       115  1,855   832
# 2  용산구  3,411  2,543     1     1     3     2       331       285  1,096   522
# 3  성동구  2,457  1,787     2     2     5     8       126       102    999   487
# 4  광진구  3,915  2,789     7     5     2     1       229       184  1,769   974
#
#    폭력 발생  폭력 검거
# 0  1,962  1,830
# 1  1,955  1,719
# 2  1,980  1,733
# 3  1,325  1,188
# 4  1,908  1,625

# %%
crime.shape
# Out:
# (25, 13)

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 13 columns):
# 구별           25 non-null object
# 합계 발생        25 non-null object
# 합계 검거        25 non-null object
# 살인 발생        25 non-null object
# 살인 검거        25 non-null object
# 강도 발생        25 non-null object
# 강도 검거        25 non-null object
# 강간강제추행 발생    25 non-null object
# 강간강제추행 검거    25 non-null object
# 절도 발생        25 non-null object
# 절도 검거        25 non-null object
# 폭력 발생        25 non-null object
# 폭력 검거        25 non-null object
# dtypes: object(13)
# memory usage: 2.7+ KB

# %%
# object에서 int로 변경됨! 
for column in list(crime.columns)[1:]:
    crime[column] = crime[column].str.replace(',', '').astype('int64')
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 13 columns):
# 구별           25 non-null object
# 합계 발생        25 non-null int64
# 합계 검거        25 non-null int64
# 살인 발생        25 non-null int64
# 살인 검거        25 non-null int64
# 강도 발생        25 non-null int64
# 강도 검거        25 non-null int64
# 강간강제추행 발생    25 non-null int64
# 강간강제추행 검거    25 non-null int64
# 절도 발생        25 non-null int64
# 절도 검거        25 non-null int64
# 폭력 발생        25 non-null int64
# 폭력 검거        25 non-null int64
# dtypes: int64(12), object(1)
# memory usage: 2.7+ KB

# %%
crime.head()
# Out:
#     구별  합계 발생  합계 검거  살인 발생  살인 검거  강도 발생  강도 검거  강간강제추행 발생  강간강제추행 검거  절도 발생  \
# 0  종로구   3690   3913      6      7      3      7        236       1100   1483
# 1   중구   4030   2679      2      2     11     11        207        115   1855
# 2  용산구   3411   2543      1      1      3      2        331        285   1096
# 3  성동구   2457   1787      2      2      5      8        126        102    999
# 4  광진구   3915   2789      7      5      2      1        229        184   1769
#
#    절도 검거  폭력 발생  폭력 검거
# 0    969   1962   1830
# 1    832   1955   1719
# 2    522   1980   1733
# 3    487   1325   1188
# 4    974   1908   1625

# %% [markdown]
# #### 서울시 자치구 년도별 CCTV 현황 데이터

# %%
cctv = pd.read_excel('서울시 자치구 년도별 CCTV 설치 현황.xlsx')
cctv.head()
# Out:
#      기관명    소계  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년
# 0  강 남 구  5221    1944.0  195.0  316.0    430    546    765    577    448
# 1  강 동 구  1879     303.0  387.0  134.0     59    144    194    273    385
# 2  강 북 구  1265     243.0   88.0  141.0     74    145    254      1    319
# 3  강 서 구  1617     219.0  155.0  118.0    230    187    190    264    254
# 4  관 악 구  3985     430.0   56.0  419.0    487    609    619    694    671

# %%
cctv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 10 columns):
# 기관명         25 non-null object
# 소계          25 non-null int64
# 2011년 이전    23 non-null float64
# 2012년       23 non-null float64
# 2013년       23 non-null float64
# 2014년       25 non-null int64
# 2015년       25 non-null int64
# 2016년       25 non-null int64
# 2017년       25 non-null int64
# 2018년       25 non-null int64
# dtypes: float64(3), int64(6), object(1)
# memory usage: 2.1+ KB

# %%
cctv = cctv.rename({'기관명': '구별'}, axis='columns')
cctv.columns.values
# Out:
# array(['구별', '소계', '2011년 이전', '2012년', '2013년', '2014년', '2015년',
#        '2016년', '2017년', '2018년'], dtype=object)

# %%
def rename_gu(x): 
    gu = x.split(' ')
    gu_new = ''.join(gu)
    return gu_new

# %%
# 이름 잘 정리됨. 
cctv['구별'] = cctv['구별'].apply(lambda x: rename_gu(x))
cctv['구별'].values
# Out:
# array(['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구',
#        '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구',
#        '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구'], dtype=object)

# %%
cctv.shape
# Out:
# (25, 10)

# %%
cctv.head()
# Out:
#     구별    소계  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년
# 0  강남구  5221    1944.0  195.0  316.0    430    546    765    577    448
# 1  강동구  1879     303.0  387.0  134.0     59    144    194    273    385
# 2  강북구  1265     243.0   88.0  141.0     74    145    254      1    319
# 3  강서구  1617     219.0  155.0  118.0    230    187    190    264    254
# 4  관악구  3985     430.0   56.0  419.0    487    609    619    694    671

# %% [markdown]
# 이후, **구별**을 기준으로 merge 해줄 것이므로 구별이 서로 같아야함!

# %%
set(cctv['구별'].unique()) - set(crime['구별'].unique())
# Out:
# set()

# %%
set(crime['구별'].unique()) - set(cctv['구별'].unique())
# Out:
# set()

# %% [markdown]
# ### 탐색적 데이터 분석
#
# #### 결측치 데이터 살피기

# %%
crime.isnull().sum()
# Out:
# 구별           0
# 합계 발생        0
# 합계 검거        0
# 살인 발생        0
# 살인 검거        0
# 강도 발생        0
# 강도 검거        0
# 강간강제추행 발생    0
# 강간강제추행 검거    0
# 절도 발생        0
# 절도 검거        0
# 폭력 발생        0
# 폭력 검거        0
# dtype: int64

# %%
cctv.isnull().sum()
# Out:
# 구별          0
# 소계          0
# 2011년 이전    2
# 2012년       2
# 2013년       2
# 2014년       0
# 2015년       0
# 2016년       0
# 2017년       0
# 2018년       0
# dtype: int64

# %%
cctv.loc[cctv.isnull()['2011년 이전'],:]
# Out:
#       구별    소계  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년
# 10  동대문구  2003       NaN    NaN    NaN   1326    111    233    136    197
# 24   중랑구  1068       NaN    NaN    NaN    770    102    121     66      9

# %%
# 2011년 이전 ~ 2013년 자료는 없으므로 0으로 처리 
cctv = cctv.fillna(0)
cctv.isnull().sum()
# Out:
# 구별          0
# 소계          0
# 2011년 이전    0
# 2012년       0
# 2013년       0
# 2014년       0
# 2015년       0
# 2016년       0
# 2017년       0
# 2018년       0
# dtype: int64

# %% [markdown]
# #### 5대 범죄 데이터 살펴보기

# %%
crime
# Out:
#       구별  합계 발생  합계 검거  살인 발생  살인 검거  강도 발생  강도 검거  강간강제추행 발생  강간강제추행 검거  \
# 0    종로구   3690   3913      6      7      3      7        236       1100
# 1     중구   4030   2679      2      2     11     11        207        115
# 2    용산구   3411   2543      1      1      3      2        331        285
# 3    성동구   2457   1787      2      2      5      8        126        102
# 4    광진구   3915   2789      7      5      2      1        229        184
# 5   동대문구   3680   2968      2      2      5      4        145        112
# 6    중랑구   4288   3222      4      5      3      3        174        145
# 7    성북구   3042   2277      7      6      1      2        183        140
# 8    강북구   3437   2743      8      6      7      7        188        135
# 9    도봉구   2249   1676      1      1      5      3        113        117
# 10   노원구   4007   2725      5      4      5      5        194        173
# 11   은평구   3590   2863      8      8      1      1        188        169
# 12  서대문구   2802   2016      5      4      3      3        206        189
# 13   마포구   5172   3569      6      6      6      7        473        396
# 14   양천구   3515   2459      2      3      4     14        120        111
# 15   강서구   4629   3469     11      9      6      3        269        246
# 16   구로구   4810   3338      8      8      9      9        250        181
# 17   금천구   3293   2567      6      6      7      6        200        185
# 18  영등포구   5840   3922     17     15      8      6        391        267
# 19   동작구   3100   2090      3      3      7      7        288        154
# 20   관악구   5026   3653      9      9     10     12        352        305
# 21   서초구   4726   3183      5      5      5      5        470        315
# 22   강남구   7513   5196     10     13     14     10        600        523
# 23   송파구   5807   4051      5      6      6      8        309        254
# 24   강동구   3919   2789      3      3      7      7        170        143
#
#     절도 발생  절도 검거  폭력 발생  폭력 검거
# 0    1483    969   1962   1830
# 1    1855    832   1955   1719
# 2    1096    522   1980   1733
# 3     999    487   1325   1188
# 4    1769    974   1908   1625
# 5    1447    930   2081   1920
# 6    1526    876   2581   2193
# 7    1164    635   1687   1494
# 8    1112    603   2122   1992
# 9     781    431   1349   1124
# 10   1422    585   2381   1958
# 11   1278    816   2115   1869
# 12   1062    585   1526   1235
# 13   2011    882   2676   2278
# 14   1384    646   2005   1685
# 15   1724    982   2619   2229
# 16   1717    787   2826   2353
# 17   1168    645   1912   1725
# 18   2292   1064   3132   2570
# 19   1151    532   1651   1394
# 20   2012   1025   2643   2302
# 21   1851    838   2395   2020
# 22   3004   1317   3885   3333
# 23   2352   1034   3135   2749
# 24   1515    765   2224   1871

# %%
# 구별 검거율 구하기 
crime['검거율'] = (crime['합계 검거'] / crime['합계 발생']) * 100
crime['살인검거율'] = (crime['살인 검거'] / crime['살인 발생']) * 100
crime['강도검거율'] = (crime['강도 검거'] / crime['강도 발생']) * 100
crime['강간검거율'] = (crime['강간강제추행 검거'] / crime['강간강제추행 발생']) * 100
crime['절도검거율'] = (crime['절도 검거'] / crime['절도 발생']) * 100
crime['폭력검거율'] = (crime['폭력 검거'] / crime['폭력 발생']) * 100

crime = crime.drop(['합계 발생','합계 검거','살인 검거', '강도 검거', '강간강제추행 검거','절도 검거','폭력 검거'],1)
crime.head()
# Out:
#     구별  살인 발생  강도 발생  강간강제추행 발생  절도 발생  폭력 발생         검거율       살인검거율  \
# 0  종로구      6      3        236   1483   1962  106.043360  116.666667
# 1   중구      2     11        207   1855   1955   66.476427  100.000000
# 2  용산구      1      3        331   1096   1980   74.552917  100.000000
# 3  성동구      2      5        126    999   1325   72.730973  100.000000
# 4  광진구      7      2        229   1769   1908   71.238825   71.428571
#
#         강도검거율       강간검거율      절도검거율      폭력검거율
# 0  233.333333  466.101695  65.340526  93.272171
# 1  100.000000   55.555556  44.851752  87.928389
# 2   66.666667   86.102719  47.627737  87.525253
# 3  160.000000   80.952381  48.748749  89.660377
# 4   50.000000   80.349345  55.059356  85.167715

# %%
crime = crime.rename({'살인 발생': '살인','강도 발생':'강도',
                      '절도 발생':'절도','폭력 발생':'폭력','강간강제추행 발생':'강간'}, axis='columns')
crime.columns.values
# Out:
# array(['구별', '살인', '강도', '강간', '절도', '폭력', '검거율', '살인검거율', '강도검거율',
#        '강간검거율', '절도검거율', '폭력검거율'], dtype=object)

# %%
crime.head()
# Out:
#     구별  살인  강도   강간    절도    폭력         검거율       살인검거율       강도검거율  \
# 0  종로구   6   3  236  1483  1962  106.043360  116.666667  233.333333
# 1   중구   2  11  207  1855  1955   66.476427  100.000000  100.000000
# 2  용산구   1   3  331  1096  1980   74.552917  100.000000   66.666667
# 3  성동구   2   5  126   999  1325   72.730973  100.000000  160.000000
# 4  광진구   7   2  229  1769  1908   71.238825   71.428571   50.000000
#
#         강간검거율      절도검거율      폭력검거율
# 0  466.101695  65.340526  93.272171
# 1   55.555556  44.851752  87.928389
# 2   86.102719  47.627737  87.525253
# 3   80.952381  48.748749  89.660377
# 4   80.349345  55.059356  85.167715

# %%
# 전년도 발생 건수에 대한 검거도 포함하기 때문에 100%를 넘김....
crime[crime['살인검거율'] >= 100]
# Out:
#       구별  살인  강도   강간    절도    폭력         검거율       살인검거율       강도검거율  \
# 0    종로구   6   3  236  1483  1962  106.043360  116.666667  233.333333
# 1     중구   2  11  207  1855  1955   66.476427  100.000000  100.000000
# 2    용산구   1   3  331  1096  1980   74.552917  100.000000   66.666667
# 3    성동구   2   5  126   999  1325   72.730973  100.000000  160.000000
# 5   동대문구   2   5  145  1447  2081   80.652174  100.000000   80.000000
# 6    중랑구   4   3  174  1526  2581   75.139925  125.000000  100.000000
# 9    도봉구   1   5  113   781  1349   74.522010  100.000000   60.000000
# 11   은평구   8   1  188  1278  2115   79.749304  100.000000  100.000000
# 13   마포구   6   6  473  2011  2676   69.006187  100.000000  116.666667
# 14   양천구   2   4  120  1384  2005   69.957326  150.000000  350.000000
# 16   구로구   8   9  250  1717  2826   69.397089  100.000000  100.000000
# 17   금천구   6   7  200  1168  1912   77.953234  100.000000   85.714286
# 19   동작구   3   7  288  1151  1651   67.419355  100.000000  100.000000
# 20   관악구   9  10  352  2012  2643   72.682053  100.000000  120.000000
# 21   서초구   5   5  470  1851  2395   67.350825  100.000000  100.000000
# 22   강남구  10  14  600  3004  3885   69.160122  130.000000   71.428571
# 23   송파구   5   6  309  2352  3135   69.760634  120.000000  133.333333
# 24   강동구   3   7  170  1515  2224   71.166114  100.000000  100.000000
#
#          강간검거율      절도검거율      폭력검거율
# 0   466.101695  65.340526  93.272171
# 1    55.555556  44.851752  87.928389
# 2    86.102719  47.627737  87.525253
# 3    80.952381  48.748749  89.660377
# 5    77.241379  64.270905  92.263335
# 6    83.333333  57.404980  84.967067
# 9   103.539823  55.185659  83.320979
# 11   89.893617  63.849765  88.368794
# 13   83.720930  43.858777  85.127055
# 14   92.500000  46.676301  84.039900
# 16   72.400000  45.835760  83.262562
# 17   92.500000  55.222603  90.219665
# 19   53.472222  46.220678  84.433677
# 20   86.647727  50.944334  87.097995
# 21   67.021277  45.272825  84.342380
# 22   87.166667  43.841545  85.791506
# 23   82.200647  43.962585  87.687400
# 24   84.117647  50.495050  84.127698

# %% [markdown]
# - [경찰청 5대 범죄 데이터](https://www.police.go.kr/www/open/publice/publice0202.jsp): 그런데 서울시만이 아닌 전국 데이터임!

# %%
from selenium import webdriver
import time

# %%
# 본인의 웹드라이버 위치 넣으세요! 
driver = webdriver.Chrome('/Users/harampark/Documents/chromedriver')
# 원하는 홈페이지로 슝~
driver.get("https://www.police.go.kr/www/open/publice/publice0202.jsp")

# %%
xpath = '//*[@id="contents2"]/div[2]/div[2]/div[4]/div/div/div[3]/div[1]/h2'
driver.find_element_by_xpath(xpath).click()

# %%
crime_table = {'2009' : [],
               '2010' : [],
               '2011' : [],
               '2012' : [],
               '2013' : [],    
              '2014' : [],
              '2015': [],
              '2016' : [],
              '2017' : [],
              '2018': []}

# %%
from bs4 import BeautifulSoup

html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
table = soup.find_all('table', class_='mb10')  # table이란 태그를 찾아라! 
df = pd.read_html(str(table))
crime_pol = df[2]
crime_pol
# Out:
#            구 분 구 분.1    2009    2010    2011    2012    2013    2014    2015  \
# 0            계    발생  590366  585637  617910  624956  606362  579057  574021
# 1            계    검거  485406  415704  383538  382248  383357  384034  411328
# 2       살인 주1)    발생    1374    1251    1204     984     918     907     919
# 3       살인 주1)    검거    1341    1228    1154     960     903     895     899
# 4           강도    발생    6346    4409    3994    2586    1978    1586    1445
# 5           강도    검거    5895    3866    3385    2239    1856    1546    1456
# 6   강간·강제추행주2)    발생   10215   18220   19491   19619   22292   21045   21280
# 7   강간·강제추행주2)    검거    9167   16104   16399   16581   19755   20026   20519
# 8           절도    발생  256590  269410  281359  290055  287704  266059  245121
# 9           절도    검거  177771  145968  112849  106060  118074  119354  126703
# 10      폭력 주3)    발생  315841  292347  311862  311712  293470  289460  305256
# 11      폭력 주3)    검거  291232  248538  249751  256408  242769  242213  261751
#
#       2016        2017    2018
# 0   535898  501978.000  488288
# 1   412462     395.798  381385
# 2      906     818.000     791
# 3      902     820.000     777
# 4     1149     965.000     818
# 5     1168     975.000     818
# 6    22193   24106.000   23467
# 7    21451   23284.000   22633
# 8   202874  183565.000  176613
# 9   118476  113625.000  106535
# 10  308776  292524.000  286599
# 11  270465  257094.000  250622

# %%
crime_pol.to_csv('경찰통계자료 5대범죄.csv', encoding='utf-8', sep=',')
driver.close()
