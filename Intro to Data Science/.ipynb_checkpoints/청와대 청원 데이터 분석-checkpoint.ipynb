# %% [markdown]
# # 청와대 청원 데이터 분석하기
#
# ## 웹크롤링

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

res = urlopen('https://www1.president.go.kr/petitions/answer?page=1') # url 넣기
soup = BeautifulSoup(res, "html.parser") # 객체 생성

# %%
contents = soup.find_all('div', class_='ans_name_title') # 원하는 태크를 이용해 찾기

for n in range(0,len(contents)):
    print(contents[n].a.get_text())

# %%
tmp_one = contents[0]
tmp_one = str(tmp_one.find('a')['href'])
url = 'https://www1.president.go.kr'+tmp_one
url

# %%
starts = soup.find_all('ol', class_='ans_name_info')

for start in starts: 
    print(start.find('p', class_='ans_list1_2').get_text()[2:-2])
    print(start.find('p', class_='ans_list2_2').get_text()[2:-2])
    print(start.find('p', class_='ans_list3_2').get_text()[2:-2])
    print(start.find('p', class_='ans_list4_2').get_text()[2:-2])
    print()

# %%
titles = []
start_date = []
end_date = []
num_consent = []
answer_date = []
address = []

def get_info(url): 
    res = urlopen(url)
    soup = BeautifulSoup(res, "html.parser")
    
    # get titles, address(url)
    contents = soup.find_all('div', class_='ans_name_title')
    for n in range(0,len(contents)):
        content = contents[n]
        titles.append(content.a.get_text())
        add_url = str(content.find('a')['href'])
        address.append('https://www1.president.go.kr'+add_url)
    
    # 청원시작과 끝 날짜, 참여인원, 답변일 정보 얻기 
    infos = soup.find_all('ol', class_='ans_name_info')
    for info in infos: 
        start_date.append(info.find('p', class_='ans_list1_2').get_text()[2:-2])
        end_date.append(info.find('p', class_='ans_list2_2').get_text()[2:-2])
        num_consent.append(info.find('p', class_='ans_list3_2').get_text()[2:-2])
        answer_date.append(info.find('p', class_='ans_list4_2').get_text()[2:-2])

# %%
for n in range(1,13): 
    url = 'https://www1.president.go.kr/petitions/answer?page=%d' % n
    get_info(url)

# %%
import pandas as pd

data = {'제목':titles, '청원시작일':start_date, '청원종료일': end_date,
       '참여인원': num_consent, 'URL':address}
df = pd.DataFrame(data)
df

# %%
df.to_csv('BlueHouse Petition data.csv', sep=',', encoding='utf-8')

# %%
import pandas as pd

petition = pd.read_csv('BlueHouse Petition data.csv', thousands=',', encoding='utf-8', index_col=0)
petition[40: 70]
# Out:
#                                                    제목         청원시작일  \
# 40                            문재인 대통령님의 탄핵을 원하지 않습니다.  2020. 02. 27
# 41         신천지 예수교 증거장막성전(이하, 신천지)의 강제 해체(해산)을 청원합니다.  2020. 02. 22
# 42            [국민청원(안)] 신천지 교주 이**의 즉각적인 구속수사를 촉구합니다.  2020. 02. 25
# 43                     텔레그램 n번방 용의자 신상공개 및 포토라인 세워주세요  2020. 03. 18
# 44                        텔레그램 n번방 가입자 전원의 신상공개를 원합니다  2020. 03. 20
# 45                          가해자 n번방박사,n번방회원 모두 처벌해주세요  2020. 03. 20
# 46                      N번방 대화 참여자들도 명단을 공개하고 처벌해주십시오  2020. 03. 20
# 47             텔레그램 아동.청소년 성노예 사건 철저한 수사 및 처벌 촉구합니다!!  2020. 03. 10
# 48                                       중국인 입국 금지 요청  2020. 01. 23
# 49                                추미애 법무장관의 해임을 청원합니다  2020. 02. 03
# 56  2019. 12. 20   208739  https://www1.president.go.kr/petitions/583677
# 57  2019. 11. 14   226434  https://www1.president.go.kr/petitions/583122
# 58  2019. 11. 28   271502  https://www1.president.go.kr/petitions/583346
# 59  2019. 12. 11   415691  https://www1.president.go.kr/petitions/583543
# 60  2019. 11. 23   215186  https://www1.president.go.kr/petitions/583272
# 61  2019. 11. 23   209397  https://www1.president.go.kr/petitions/583277
# 62  2019. 11. 20   306638  https://www1.president.go.kr/petitions/583190
# 63  2019. 11. 13   209133  https://www1.president.go.kr/petitions/583076
# 64  2019. 11. 09   213306  https://www1.president.go.kr/petitions/583046
# 65  2019. 10. 23   250092  https://www1.president.go.kr/petitions/582785
# 66  2019. 10. 10   227314  https://www1.president.go.kr/petitions/582620
# 67  2019. 09. 27   365040  https://www1.president.go.kr/petitions/582349
# 68  2019. 09. 27   481076  https://www1.president.go.kr/petitions/582351
# 69  2019. 09. 25   229202  https://www1.president.go.kr/petitions/582301

# %%
res = urlopen('https://www1.president.go.kr/petitions/5833426') # url 넣기
soup = BeautifulSoup(res, "html.parser") # 객체 생성

category = soup.find('ul', class_='petitionsView_info_list')
category

# %%
content = soup.find_all('div', class_='View_write')
tmp_one = content[1].get_text()
tmp_one

# %%
import re 

tmp_one_split = re.split('\r|\t|\n', tmp_one)
tmp_one_new = ''.join(tmp_one_split)
tmp_one_new

# %%
res = urlopen('https://www1.president.go.kr/petitions/45581') # url 넣기
soup = BeautifulSoup(res, "html.parser") # 객체 생성

answers = soup.find_all('div', class_='pr_tk25')
answers_raw = re.split("\r|\t|\n|\xa0", answers[1].get_text())
answers_new = ' '.join(answers_raw)
answers_new[7:]

# %%
import re 
import time
from tqdm import tqdm_notebook
from urllib.request import urlopen
from bs4 import BeautifulSoup

category =[]
content = []
answer = []

for n in range(0,60): 
    url_base = urlopen(petition['URL'][n]) 
    # time.sleep(1)
    soup = BeautifulSoup(url_base, "html.parser") 
    # time.sleep(1)
    
    # get category 
    sector = soup.find('ul', class_='petitionsView_info_list')
    try: 
        category.append(sector.li.get_text()[4:])
    except AttributeError:
        print('AttributeError: index-', n, 'URL-', petition['URL'][n])
    
    # get petition content 
    content_raw = soup.find_all('div', class_='View_write')
    if len(content_raw) > 1: 
        try: 
            content_raw_text = content_raw[1].get_text()
        except IndexError: 
            print('IndexError:', petition['URL'][n])
    else: 
        content_raw_text = content_raw[0].get_text()
    
    content_split = re.split('\r|\t|\n', content_raw_text)
    content.append(''.join(content_split))

    # get petition answer 
    answer_raw = soup.find_all('div', class_='pr_tk25')
    if len(answer_raw) > 1: 
        answer_raw_text = re.split("\r|\t|\n|\xa0", answer_raw[1].get_text())
    else: 
        answer_raw_text = re.split("\r|\t|\n|\xa0", answer_raw[0].get_text())
    answer_raw_text = ' '.join(answer_raw_text)
    answer.append(answer_raw_text[7:]) 
    
    # time.sleep(1)

# %%
len(category)
# Out:
# 60

# %%
len(content)
# Out:
# 60

# %%
len(answer)
# Out:
# 60

# %%
petition['URL'][60]
# Out:
# 'https://www1.president.go.kr/petitions/583272'
